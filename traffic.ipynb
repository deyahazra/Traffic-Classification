# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from PIL import Image
import os
from sklearn.model_selection import train_test_split 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
import matplotlib.pyplot as plt
import plotly.express as px
import random

# %%
inputBasePath = '/data'

# %%
trainingFolder = 'traffic_Data/DATA'
testingFolder = 'traffic_Data/TEST'
classes = pd.read_csv('labels.csv')
classes_size = len(classes)
print("Total number of classes: ", classes_size)
# Out:
# Total number of classes:  58

# %%
traffic_data = []
training_data = []
labels = []
def fetch_images(traffic_data, labels):
    for classValue in os.listdir(trainingFolder):
        classPath = os.path.join(trainingFolder, classValue)
        labels.append(classValue)
        for trafficSignal in os.listdir(classPath):
            imgTrafficSignal = Image.open(os.path.join(classPath,trafficSignal))
            imgTrafficSignal = imgTrafficSignal.convert("L")
            imgTrafficSignal = imgTrafficSignal.resize((90,90))
            imgTrafficSignal = np.array(imgTrafficSignal)
            traffic_data.append((imgTrafficSignal,[int(classValue)]))
    #training_data = np.array(training_data)
    labels = np.array(labels)
    return traffic_data, labels

# %%
traffic_data, labels = fetch_images(traffic_data, labels)
traffic_data_features, traffic_data_labels = zip(*traffic_data)
training_data_features, validation_data_features, training_data_labels, validation_data_labels = train_test_split(traffic_data_features, traffic_data_labels, test_size=0.33, random_state=42)
training_data_features = np.array(training_data_features)
training_data_labels = np.array(training_data_labels)
validation_data_features = np.array(validation_data_features)
validation_data_labels = np.array(validation_data_labels)
print(training_data_features.shape)
print(training_data_labels.shape)
# Out:
# (2793, 90, 90)
# (2793, 1)

# %%
def imageDisplayer(data_features, data_labels_act, data_labels_pred=None):
    rows, cols = 6, 4
    fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

    plt.subplots_adjust(wspace=0, hspace=0.5) 
    if data_labels_pred is not None:
        for row in range(rows):
            for col in range(cols):
                i = row * cols + col  # Calculate the index
                randomVal = random.randint(1,2)
                # Get the image and label for the current index
                display_image = data_features[i*randomVal]
                display_label_act = classes['Name'][data_labels_act[i*randomVal][0]]
                display_label_pred = classes['Name'][data_labels_pred[i*randomVal]]

                # Display the image
                axes[row, col].imshow(display_image) 
                axes[row, col].set_title((display_label_act, display_label_pred))
                axes[row, col].axis('off')
    else:
        for row in range(rows):
            for col in range(cols):
                i = row * cols + col  # Calculate the index
                randomVal = random.randint(1,2)
                # Get the image and label for the current index
                display_image = data_features[i*randomVal]
                display_label = classes['Name'][data_labels_act[i*randomVal][0]]

                # Display the image
                axes[row, col].imshow(display_image) 
                axes[row, col].set_title(display_label)
                axes[row, col].axis('off')
imageDisplayer(training_data_features, training_data_labels)

# %%
def convolutionModel():
    cnnModel = Sequential()
    cnnModel.add(Conv2D(16,(3,3), padding="same", input_shape=(90, 90, 1), activation='relu'))
#     print(cnnModel(training_data_features).shape)
    cnnModel.add(MaxPool2D((2,2), strides=None, padding="same"))
    cnnModel.add(Conv2D(32,(3,3), padding="same", activation='relu'))
    cnnModel.add(MaxPool2D((2,2), strides=None, padding="same"))
    cnnModel.add(Conv2D(64,(5,5), padding="same", activation='relu'))
    cnnModel.add(MaxPool2D((2,2), strides=None, padding="same"))
    cnnModel.add(Conv2D(128,(7,7), padding="same", activation='relu'))
    cnnModel.add(MaxPool2D((2,2), strides=None, padding="same"))
    cnnModel.add(Flatten())
    cnnModel.add(Dense(232, activation='relu'))
    cnnModel.add(Dense(116, activation='relu'))
    cnnModel.add(Dense(58, activation='softmax'))
    return cnnModel

# %%
epochs = 60
batchSize = 14
cnnModel = convolutionModel()
cnnModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 90, 90, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 45, 45, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       401536
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 232)               1069288
#
#  dense_1 (Dense)             (None, 116)               27028
#
#  dense_2 (Dense)             (None, 58)                6786
#
# =================================================================
# Total params: 1,560,702
# Trainable params: 1,560,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(training_data_features.shape, training_data_labels.shape)
print(training_data_labels)
# Out:
# (2793, 90, 90) (2793, 1)
# [[28]
#  [54]
#  [11]
#  ...
#  [ 5]
#  [55]
#  [17]]

# %%
cnnModel.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
trafficSignNetwork = cnnModel.fit(training_data_features, training_data_labels, batch_size=batchSize, epochs=epochs, validation_data=(validation_data_features, validation_data_labels))
# Out:
# Epoch 1/60
# C:\Users\deyah\anaconda3\envs\tensorgpu\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 200/200 [==============================] - 8s 16ms/step - loss: 3.2375 - accuracy: 0.3398 - val_loss: 1.5502 - val_accuracy: 0.6507
# Epoch 2/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.9813 - accuracy: 0.7447 - val_loss: 0.5826 - val_accuracy: 0.8656
# Epoch 3/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.3907 - accuracy: 0.8983 - val_loss: 0.5166 - val_accuracy: 0.8577
# Epoch 4/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2488 - accuracy: 0.9327 - val_loss: 0.2522 - val_accuracy: 0.9434
# Epoch 5/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1637 - accuracy: 0.9549 - val_loss: 0.3173 - val_accuracy: 0.9187
# Epoch 6/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1160 - accuracy: 0.9685 - val_loss: 0.2613 - val_accuracy: 0.9434
# Epoch 7/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1881 - accuracy: 0.9488 - val_loss: 0.4042 - val_accuracy: 0.9121
# Epoch 8/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1508 - accuracy: 0.9646 - val_loss: 0.2755 - val_accuracy: 0.9506
# Epoch 9/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0526 - accuracy: 0.9868 - val_loss: 0.2362 - val_accuracy: 0.9513
# Epoch 10/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0366 - accuracy: 0.9893 - val_loss: 0.2501 - val_accuracy: 0.9528
# Epoch 11/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0753 - accuracy: 0.9807 - val_loss: 0.2386 - val_accuracy: 0.9601
# Epoch 12/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1092 - accuracy: 0.9692 - val_loss: 0.2194 - val_accuracy: 0.9572
# Epoch 13/60
# 200/200 [==============================] - 2s 12ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.3868 - val_accuracy: 0.9434
# Epoch 14/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0840 - accuracy: 0.9799 - val_loss: 1.3375 - val_accuracy: 0.8475
# Epoch 15/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1036 - accuracy: 0.9721 - val_loss: 0.2445 - val_accuracy: 0.9630
# Epoch 16/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0361 - accuracy: 0.9914 - val_loss: 0.2963 - val_accuracy: 0.9608
# Epoch 17/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0841 - accuracy: 0.9803 - val_loss: 0.3095 - val_accuracy: 0.9499
# Epoch 18/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0771 - accuracy: 0.9803 - val_loss: 0.3150 - val_accuracy: 0.9521
# Epoch 19/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0345 - accuracy: 0.9910 - val_loss: 0.3624 - val_accuracy: 0.9521
# Epoch 20/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0571 - accuracy: 0.9903 - val_loss: 0.3531 - val_accuracy: 0.9557
# Epoch 21/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0707 - accuracy: 0.9875 - val_loss: 0.2190 - val_accuracy: 0.9688
# Epoch 22/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0312 - accuracy: 0.9925 - val_loss: 0.2852 - val_accuracy: 0.9564
# Epoch 23/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0837 - accuracy: 0.9799 - val_loss: 0.3859 - val_accuracy: 0.9368
# Epoch 24/60
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1276 - accuracy: 0.9774 - val_loss: 0.3028 - val_accuracy: 0.9368
# Epoch 25/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0451 - accuracy: 0.9878 - val_loss: 0.3122 - val_accuracy: 0.9586
# Epoch 26/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0790 - accuracy: 0.9832 - val_loss: 0.3533 - val_accuracy: 0.9528
# Epoch 27/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0408 - accuracy: 0.9896 - val_loss: 0.3285 - val_accuracy: 0.9630
# Epoch 28/60
# 200/200 [==============================] - 3s 13ms/step - loss: 0.0020 - accuracy: 0.9989 - val_loss: 0.2971 - val_accuracy: 0.9710
# Epoch 29/60
# 200/200 [==============================] - 3s 13ms/step - loss: 4.0510e-05 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9724
# Epoch 30/60
# 200/200 [==============================] - 3s 13ms/step - loss: 2.8888e-05 - accuracy: 1.0000 - val_loss: 0.2953 - val_accuracy: 0.9724
# Epoch 31/60
# 200/200 [==============================] - 3s 13ms/step - loss: 2.2673e-05 - accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.9724
# Epoch 32/60
# 200/200 [==============================] - 3s 13ms/step - loss: 1.8854e-05 - accuracy: 1.0000 - val_loss: 0.2937 - val_accuracy: 0.9724
# Epoch 33/60
# 200/200 [==============================] - 3s 13ms/step - loss: 1.5806e-05 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9739
# Epoch 34/60
# 200/200 [==============================] - 3s 13ms/step - loss: 1.3456e-05 - accuracy: 1.0000 - val_loss: 0.2899 - val_accuracy: 0.9739
# Epoch 35/60
# 200/200 [==============================] - 2s 13ms/step - loss: 1.1571e-05 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9739
# Epoch 36/60
# 200/200 [==============================] - 3s 13ms/step - loss: 9.7953e-06 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.9753
# Epoch 37/60
# 200/200 [==============================] - 3s 13ms/step - loss: 8.3733e-06 - accuracy: 1.0000 - val_loss: 0.2926 - val_accuracy: 0.9739
# Epoch 38/60
# 200/200 [==============================] - 3s 13ms/step - loss: 7.1745e-06 - accuracy: 1.0000 - val_loss: 0.2939 - val_accuracy: 0.9739
# Epoch 39/60
# 200/200 [==============================] - 3s 13ms/step - loss: 6.2231e-06 - accuracy: 1.0000 - val_loss: 0.2958 - val_accuracy: 0.9739
# Epoch 40/60
# 200/200 [==============================] - 3s 13ms/step - loss: 5.3736e-06 - accuracy: 1.0000 - val_loss: 0.2983 - val_accuracy: 0.9724
# Epoch 41/60
# 200/200 [==============================] - 3s 13ms/step - loss: 4.5657e-06 - accuracy: 1.0000 - val_loss: 0.3012 - val_accuracy: 0.9724
# Epoch 42/60
# 200/200 [==============================] - 3s 13ms/step - loss: 3.8418e-06 - accuracy: 1.0000 - val_loss: 0.3030 - val_accuracy: 0.9724
# Epoch 43/60
# 200/200 [==============================] - 3s 13ms/step - loss: 3.3525e-06 - accuracy: 1.0000 - val_loss: 0.3036 - val_accuracy: 0.9724
# Epoch 44/60
# 200/200 [==============================] - 3s 13ms/step - loss: 2.9034e-06 - accuracy: 1.0000 - val_loss: 0.3052 - val_accuracy: 0.9724
# Epoch 45/60
# 200/200 [==============================] - 3s 13ms/step - loss: 2.5644e-06 - accuracy: 1.0000 - val_loss: 0.3053 - val_accuracy: 0.9724
# Epoch 46/60
# 200/200 [==============================] - 2s 12ms/step - loss: 2.3070e-06 - accuracy: 1.0000 - val_loss: 0.3069 - val_accuracy: 0.9724
# Epoch 47/60
# 200/200 [==============================] - 3s 13ms/step - loss: 2.0460e-06 - accuracy: 1.0000 - val_loss: 0.3083 - val_accuracy: 0.9724
# Epoch 48/60
# 200/200 [==============================] - 3s 13ms/step - loss: 1.8290e-06 - accuracy: 1.0000 - val_loss: 0.3095 - val_accuracy: 0.9724
# Epoch 49/60
# 200/200 [==============================] - 3s 13ms/step - loss: 1.6405e-06 - accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.9724
# Epoch 50/60
# 200/200 [==============================] - 3s 13ms/step - loss: 1.4603e-06 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9724
# Epoch 51/60
# 200/200 [==============================] - 3s 14ms/step - loss: 1.3059e-06 - accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9724
# Epoch 52/60
# 200/200 [==============================] - 3s 13ms/step - loss: 1.1714e-06 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9724
# Epoch 53/60
# 200/200 [==============================] - 2s 12ms/step - loss: 1.0483e-06 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9724
# Epoch 54/60
# 200/200 [==============================] - 3s 13ms/step - loss: 9.3635e-07 - accuracy: 1.0000 - val_loss: 0.3143 - val_accuracy: 0.9724
# Epoch 55/60
# 200/200 [==============================] - 3s 14ms/step - loss: 8.3632e-07 - accuracy: 1.0000 - val_loss: 0.3151 - val_accuracy: 0.9724
# Epoch 56/60
# 200/200 [==============================] - 3s 13ms/step - loss: 7.4998e-07 - accuracy: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.9724
# Epoch 57/60
# 200/200 [==============================] - 3s 13ms/step - loss: 6.3935e-07 - accuracy: 1.0000 - val_loss: 0.3166 - val_accuracy: 0.9724
# Epoch 58/60
# 200/200 [==============================] - 3s 13ms/step - loss: 5.6176e-07 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 0.9724
# Epoch 59/60
# 200/200 [==============================] - 3s 13ms/step - loss: 4.9040e-07 - accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 0.9724
# Epoch 60/60
# 200/200 [==============================] - 3s 13ms/step - loss: 4.3393e-07 - accuracy: 1.0000 - val_loss: 0.3198 - val_accuracy: 0.9724

# %%
plt.plot(trafficSignNetwork.history['accuracy'], label='accuracy')

# %%
testing_data = []
for test_image_file in os.listdir(os.path.join( testingFolder)):
    testImage = Image.open(os.path.join(testingFolder, test_image_file))
    testImage = testImage.convert("L")
    testImage = testImage.resize((90,90))
    testImage = np.array(testImage)
    testing_data.append((testImage, [int(test_image_file[1:3])]))
testing_data_features, testing_data_labels = zip(*testing_data)
testing_data_features = np.array(testing_data_features)
testing_data_labels = np.array(testing_data_labels)

# %%
predictions = cnnModel.predict(testing_data_features)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# 63/63 [==============================] - 1s 7ms/step

# %%
print(classes['Name'][predicted_labels])
print(classes['Name'][testing_data_labels[:,0]])
plt.imshow(testing_data_features[1])
# Out:
# 4     Speed limit (50km/h)
# 0      Speed limit (5km/h)
# 0      Speed limit (5km/h)
# 0      Speed limit (5km/h)
# 0      Speed limit (5km/h)
#               ...
# 23        Go Left or right
# 57                Unknown8
# 57                Unknown8
# 57                Unknown8
# 57                Unknown8
# Name: Name, Length: 1994, dtype: object
# 0     Speed limit (5km/h)
# 0     Speed limit (5km/h)
# 0     Speed limit (5km/h)
# 0     Speed limit (5km/h)
# 0     Speed limit (5km/h)
#              ...
# 56               Unknown7
# 57               Unknown8
# 57               Unknown8
# 57               Unknown8
# 57               Unknown8
# Name: Name, Length: 1994, dtype: object

# %%
imageDisplayer(testing_data_features, testing_data_labels, predicted_labels)

# %%
test_loss, test_acc = cnnModel.evaluate(testing_data_features, testing_data_labels, verbose=2)
print(test_acc)
# Out:
# 63/63 - 1s - loss: 5.3489 - accuracy: 0.5988 - 612ms/epoch - 10ms/step
# 0.5987963676452637

# %%
cnnModel.save('my_model.h5')
